# %% [markdown]
# <a href="https://colab.research.google.com/github/sayedakhan/HHA504_Practice/blob/main/10_4_Assgnmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# %%
jsonResponse = requests.get('https://disease.sh/v3/covid-19/historical/all?lastdays=all')
jsonResponse.status_code
# Out:
# 200

# %%
jsonResponse.json()
# Out:
# {'cases': {'1/1/21': 84203945,
#   '1/10/21': 90432702,
#   '1/11/21': 91049524,
#   '1/12/21': 91746747,
#   '1/13/21': 92494424,
#   '1/14/21': 93252210,
#   '1/15/21': 94022870,
#   '1/16/21': 94668101,
#   '1/17/21': 95195726,
#   '1/18/21': 95707779,
#   '1/19/21': 96305234,
#   '1/2/21': 84789834,
#   '1/20/21': 97000167,
#   '1/21/21': 97654938,
#   '1/22/20': 557,
#   '1/22/21': 98312298,
#   '1/23/20': 655,
#   '1/23/21': 98883925,
#   '1/24/20': 941,
#   '1/24/21': 99335895,
#   '1/25/20': 1434,
#   '1/25/21': 99824124,
#   '1/26/20': 2118,
#   '1/26/21': 100377338,
#   '1/27/20': 2927,
#   '1/27/21': 100977028,
#   '1/28/20': 5578,
#   '1/28/21': 101589013,
#   '1/29/20': 6167,
#   '1/29/21': 102179630,
#   '1/3/21': 85311618,
#   '1/30/20': 8235,
#   '1/30/21': 102697256,
#   '1/31/20': 9927,
#   '1/31/21': 103081819,
#   '1/4/21': 85862769,
#   '1/5/21': 86599074,
#   '1/6/21': 87383666,
#   '1/7/21': 88275187,
#   '1/8/21': 89086319,
#   '1/9/21': 89844616,
# ...
